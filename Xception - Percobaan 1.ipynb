# %% [markdown]
# <a href="https://colab.research.google.com/github/noprisigit/Xception/blob/main/Xception%20-%20Percobaan%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %%
# Mount Google Drive
drive.mount('/content/drive')

# !unzip '/content/drive/MyDrive/iarc-annocerv-master-dataset-balanced-split.zip'
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/MyDrive/iarc-annocerv-master-dataset-balanced-split.zip
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_134.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C56Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_115.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_146.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_119.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_131.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_136.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AABG2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AAHQ2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_127.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C63Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_118.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AACT09.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C15Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C12Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_105.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AAGQ2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C34Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AACA1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C12Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AABL1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AAAB3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_140.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C87Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_135.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AAHP2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AABH2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_124.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C87Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_139.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C55Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AADF5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AACT07.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_146.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C63Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_115.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C73Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AACZ5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_127.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AAEY3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_119.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C13Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AABJ1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C92Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_125.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_134.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C83Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/aug_144.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_140.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C73Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C87Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_131.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_118.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AABI3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C28Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C13Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AAFG1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_136.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/AACM2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AAIH3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C13Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_124.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_105.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_135.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AAIA2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C23Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C60Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AADR04.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C47Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C99Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AAIE1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 2/C7Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C26Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AADQ10.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C85Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_125.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_140.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_139.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AAFM2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AAEX1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C91Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AAHD3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_104.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AADF4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AAIA1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AACG1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_134.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C1Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_96.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/AADQ01.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_115.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C71Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C60Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C99Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_146.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AABX17.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C38Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C74Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AACK4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/C100Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C22Aceto (1) (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_119.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C3Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_127.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AABM5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AAJB2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AABP5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AAIY2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C82Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C58Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C46Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AACC2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AAEV2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C51Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C17Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C22Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AAHT3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_131.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C57Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_136.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AABT3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C48Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_118.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C18Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C25Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C74Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AACN3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AABV2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C70Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_135.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C41Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AAHT5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C40Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C88Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/Normal/aug_144.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C62Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AABA2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C22Aceto (4) (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C66Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C22Aceto (2) (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_124.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C71Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AAJJ2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C85Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AABX19.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AAGP2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C24Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C76Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C16Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C25Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_144.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C4Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AABB2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C57Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C3Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C79Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C71Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C44Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C90Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C84Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C84Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AABC1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AAJJ4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/C33Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C27Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_125.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/aug_139.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AABM1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C78Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C27Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AAIW1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AAES2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C85Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C84Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AABQ7.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AACC0.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AAEM2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C22Aceto (5) (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 3/AABP2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C24Aceto (1) (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AAHN2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AADJ5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C43Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C22Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C30Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C52Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C90Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C42Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C64Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C10Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C65Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C89Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C65Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C75Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AAAX4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C98Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C10Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C20Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C41Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C20Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C2Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C31Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C98Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C51Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C11Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C88Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C11Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C91Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C85Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C30Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C58Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C18Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/AACK2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C31Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AAAY04.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C40Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C89Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C45Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C82Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C80Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C26Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C24Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C62Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C20Aceto (3) (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C98Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C64Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C20Aceto (1) (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C89Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C97Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C42Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C4Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C80Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/AABA1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C80Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C51Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C10Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C2Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C26Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/AABD1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C22Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C25Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C52Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C5Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C31Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C75Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C97Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C74Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C3Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C43Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/AAAX5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C75Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C40Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C22Aceto (3) (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C66Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C31Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C62Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C70Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C64Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C70Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AAAZ4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C40Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C52Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C46Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C20Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C5Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C3Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AAEJ1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C82Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C2Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C45Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C27Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C88Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C78Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C31Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AACI4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C5Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C22Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C66Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C80Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C40Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/AACI3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C26Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C18Aceto (2) (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C49Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_138.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C22Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AAGY4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C42Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C24Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_147.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/AACI1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C51Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C61Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C44Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C17Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C6Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C16Aceto (6).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACR2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C76Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C93Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_129.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/val/CIN 1/C42Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_116.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C81Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C68Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACR5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C44Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACR3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACF2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_142.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_121.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C33Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABN4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AAJI2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C6Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABS05.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 1/C20Aceto (2) (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABR10.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C57Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_145.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C79Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_130.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AAHT2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABX15.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_123.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C81Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_137.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C57Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_113.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_128.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACX2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACU4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACB2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C86Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_133.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AAIY3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C68Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACU6.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_111.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABR14.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C16Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C16Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACX3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AAHS2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AAJI3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C79Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C6Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACN2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AAHU4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C79Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_132.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C48Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABX08.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C76Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C16Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_112.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AAGP4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C48Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_120.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C86Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACV03.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABS04.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABM3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACV06.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACY3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C59Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_122.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AAHU6.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C6Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_110.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C33Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACU5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACY4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C33Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C72Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABZ09.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C33Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_117.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_143.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C61Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AAHU3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_126.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C16Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABP8.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABV3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_114.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C6Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABR08.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_147.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_121.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_106.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_142.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AABS06.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C59Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_130.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AABG1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C8Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AACW3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C68Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/aug_141.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_116.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C93Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C34Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/C59Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C63Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C69Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C21Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C12Aceto (6).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C83Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_138.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C7Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C53Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 3/AAEV3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AACD2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C8Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_113.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_107.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C53Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AABL2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C12Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_129.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C21Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AAHR2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C7Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C8Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AACO5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_112.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_128.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C69Aceto (6).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_122.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C69Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C8Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C19Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AACM0.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C14Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_137.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C12Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AACA2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AAHO2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C63Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C55Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C69Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_109.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C92Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C67Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_145.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C15Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C69Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AAAN3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_132.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_133.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C50Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_123.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_126.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C21Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C15Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C12Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_110.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AAHR3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_120.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C19Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AAJK3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C15Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C29Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C7Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_117.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C21Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C73Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C19Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_92.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_114.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_111.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C14Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AAJK4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C29Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C35Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_143.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AACO2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C50Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AADM5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAIU3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AABK0.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_108.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_102.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C34Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AABH4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_106.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C15Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AABL0.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AABK1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C92Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C29Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C69Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AAHQ1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAJL3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_99.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C7Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_138.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C53Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C47Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C63Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_130.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_147.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AABH7.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C53Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_107.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAEF04.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AADQ08.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_90.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AACD5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C28Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/AAGQ4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C32Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_112.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C13Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_129.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_109.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAEF05.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C38Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_91.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C100Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C1Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C96Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_116.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/aug_141.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_103.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C95Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C54Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_145.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_100.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_142.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAIU4.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C13Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_122.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AADS5.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C36Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_95.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_137.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAFM1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_111.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C32Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C37Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C96Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C39Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_113.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C54Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/CIN 2/C56Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AADS1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_128.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C32Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C60Aceto (5).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAFB3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C23Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_123.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C36Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_98.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_133.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAJE2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_89.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C60Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C28Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C28Aceto (4).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AACJ3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C9Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C39Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C60Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C96Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C85Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAHE.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_94.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_126.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_114.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C85Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C1Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_97.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AADR09.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C77Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C94Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAJE1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AADS2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C94Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_120.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_117.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C37Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_132.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C23Aceto (3).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C95Aceto (1).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_93.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_121.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AADR05.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAFG0.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAEY1.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C100Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C77Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_101.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAFG2.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_143.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/AAHE3.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/C9Aceto (2).jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_110.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_141.jpg
#   inflating: iarc-annocerv-master-dataset-balanced-split/train/Normal/aug_108.jpg

# %%
# Dataset Path
data_dir = '/content/iarc-annocerv-master-dataset-balanced-split'
train_dir = os.path.join(data_dir, 'train')
val_dir = os.path.join(data_dir, 'val')

# Count Dataset
def count_dataset(directory):
  class_counts = {}
  total_count = 0

  for class_name in os.listdir(directory):
    class_path = os.path.join(directory, class_name)
    if (os.path.isdir(class_path)):
      num_images = len(os.listdir(class_path))
      class_counts[class_name] = num_images
      total_count += num_images

  return class_counts, total_count

total_images, class_distribution = count_dataset(train_dir)
print(f'Total Images Training: {total_images}')
print('Class Distribution Training:', class_distribution)

total_images, class_distribution = count_dataset(val_dir)
print(f'Total Images Validation: {total_images}')
print('Class Distribution Validation:', class_distribution)
# Out:
# Total Images Training: {'CIN 1': 110, 'Normal': 103, 'CIN 3': 103, 'CIN 2': 103}
# Class Distribution Training: 419
# Total Images Validation: {'CIN 1': 48, 'Normal': 45, 'CIN 3': 45, 'CIN 2': 45}
# Class Distribution Validation: 183

# %%
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32

# Augmentasi data untuk train set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    zoom_range=0.2,
    rotation_range=70,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
)
# train_datagen = ImageDataGenerator(rescale=1./255)

# Hanya rescale untuk validation dan test set
val_test_datagen = ImageDataGenerator(
    rescale=1./255,
)

# Data generator untuk train, validation, dan test set
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True,
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='rgb',

    shuffle=False,
)
# Out:
# Found 419 images belonging to 4 classes.
# Found 183 images belonging to 4 classes.

# %%
# Display Sample Images
# def plot_sample_images(generator):
#   class_names = list(generator.class_indices.keys())
#   plt.figure(figsize=(10, 5))

#   for i in range(6):
#     img, label = next(generator)
#     plt.subplot(2, 3, i + 1)
#     plt.imshow(img[0])
#     plt.title(class_names[np.argmax(label[0])])
#     plt.axis('off')

#   plt.show()

# plot_sample_images(train_generator)

# %%
# Hitung Class Weighs

class_indices = train_generator.class_indices
print("Class indices:", class_indices)

labels = train_generator.classes  # array of class index per sample
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)

class_weights = dict(enumerate(class_weights))
print("Class weights:", class_weights)
# Out:
# Class indices: {'CIN 1': 0, 'CIN 2': 1, 'CIN 3': 2, 'Normal': 3}
# Class weights: {0: np.float64(0.9522727272727273), 1: np.float64(1.016990291262136), 2: np.float64(1.016990291262136), 3: np.float64(1.016990291262136)}

# %%
# Load MobileNetV2 dengan weights 'imagenet' dan tanpa top layer
base_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze base model
for layer in base_model.layers:
    layer.trainable = False

# Tambahkan custom top layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(4, activation='softmax')(x)

# Bangun model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 111, 111,  │        864 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, 111, 111,  │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_act    │ (None, 111, 111,  │          0 │ block1_conv1_bn[… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 109, 109,  │     18,432 │ block1_conv1_act… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_bn     │ (None, 109, 109,  │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_act    │ (None, 109, 109,  │          0 │ block1_conv2_bn[… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1     │ (None, 109, 109,  │      8,768 │ block1_conv2_act… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1_bn  │ (None, 109, 109,  │        512 │ block2_sepconv1[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_act │ (None, 109, 109,  │          0 │ block2_sepconv1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2     │ (None, 109, 109,  │     17,536 │ block2_sepconv2_… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_bn  │ (None, 109, 109,  │        512 │ block2_sepconv2[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 55, 55,    │      8,192 │ block1_conv2_act… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 55, 55,    │          0 │ block2_sepconv2_… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 55, 55,    │        512 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 55, 55,    │          0 │ block2_pool[0][0… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_act │ (None, 55, 55,    │          0 │ add[0][0]         │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1     │ (None, 55, 55,    │     33,920 │ block3_sepconv1_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_bn  │ (None, 55, 55,    │      1,024 │ block3_sepconv1[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_act │ (None, 55, 55,    │          0 │ block3_sepconv1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2     │ (None, 55, 55,    │     67,840 │ block3_sepconv2_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_bn  │ (None, 55, 55,    │      1,024 │ block3_sepconv2[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 28, 28,    │     32,768 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_sepconv2_… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      1,024 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 28, 28,    │          0 │ block3_pool[0][0… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_act │ (None, 28, 28,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1     │ (None, 28, 28,    │    188,672 │ block4_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_bn  │ (None, 28, 28,    │      2,912 │ block4_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_act │ (None, 28, 28,    │          0 │ block4_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2     │ (None, 28, 28,    │    536,536 │ block4_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_bn  │ (None, 28, 28,    │      2,912 │ block4_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 14, 14,    │    186,368 │ add_1[0][0]       │
# │                     │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_sepconv2_… │
# │ (MaxPooling2D)      │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,912 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 14, 14,    │          0 │ block4_pool[0][0… │
# │                     │ 728)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_act │ (None, 14, 14,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1     │ (None, 14, 14,    │    536,536 │ block5_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_act │ (None, 14, 14,    │          0 │ block5_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2     │ (None, 14, 14,    │    536,536 │ block5_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_act │ (None, 14, 14,    │          0 │ block5_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3     │ (None, 14, 14,    │    536,536 │ block5_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 14, 14,    │          0 │ block5_sepconv3_… │
# │                     │ 728)              │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_act │ (None, 14, 14,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1     │ (None, 14, 14,    │    536,536 │ block6_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_act │ (None, 14, 14,    │          0 │ block6_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2     │ (None, 14, 14,    │    536,536 │ block6_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_act │ (None, 14, 14,    │          0 │ block6_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3     │ (None, 14, 14,    │    536,536 │ block6_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 14, 14,    │          0 │ block6_sepconv3_… │
# │                     │ 728)              │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_act │ (None, 14, 14,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1     │ (None, 14, 14,    │    536,536 │ block7_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_act │ (None, 14, 14,    │          0 │ block7_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2     │ (None, 14, 14,    │    536,536 │ block7_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_act │ (None, 14, 14,    │          0 │ block7_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3     │ (None, 14, 14,    │    536,536 │ block7_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 14, 14,    │          0 │ block7_sepconv3_… │
# │                     │ 728)              │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_act │ (None, 14, 14,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1     │ (None, 14, 14,    │    536,536 │ block8_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_act │ (None, 14, 14,    │          0 │ block8_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2     │ (None, 14, 14,    │    536,536 │ block8_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_act │ (None, 14, 14,    │          0 │ block8_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3     │ (None, 14, 14,    │    536,536 │ block8_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 14, 14,    │          0 │ block8_sepconv3_… │
# │                     │ 728)              │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_act │ (None, 14, 14,    │          0 │ add_6[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1     │ (None, 14, 14,    │    536,536 │ block9_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_act │ (None, 14, 14,    │          0 │ block9_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2     │ (None, 14, 14,    │    536,536 │ block9_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_act │ (None, 14, 14,    │          0 │ block9_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3     │ (None, 14, 14,    │    536,536 │ block9_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 14, 14,    │          0 │ block9_sepconv3_… │
# │                     │ 728)              │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_a… │ (None, 14, 14,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1    │ (None, 14, 14,    │    536,536 │ block10_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_a… │ (None, 14, 14,    │          0 │ block10_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2    │ (None, 14, 14,    │    536,536 │ block10_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_a… │ (None, 14, 14,    │          0 │ block10_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3    │ (None, 14, 14,    │    536,536 │ block10_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 14, 14,    │          0 │ block10_sepconv3… │
# │                     │ 728)              │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_a… │ (None, 14, 14,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1    │ (None, 14, 14,    │    536,536 │ block11_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_a… │ (None, 14, 14,    │          0 │ block11_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2    │ (None, 14, 14,    │    536,536 │ block11_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_a… │ (None, 14, 14,    │          0 │ block11_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3    │ (None, 14, 14,    │    536,536 │ block11_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 14, 14,    │          0 │ block11_sepconv3… │
# │                     │ 728)              │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_a… │ (None, 14, 14,    │          0 │ add_9[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1    │ (None, 14, 14,    │    536,536 │ block12_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_a… │ (None, 14, 14,    │          0 │ block12_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2    │ (None, 14, 14,    │    536,536 │ block12_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_a… │ (None, 14, 14,    │          0 │ block12_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3    │ (None, 14, 14,    │    536,536 │ block12_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 14, 14,    │          0 │ block12_sepconv3… │
# │                     │ 728)              │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_a… │ (None, 14, 14,    │          0 │ add_10[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1    │ (None, 14, 14,    │    536,536 │ block13_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block13_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_a… │ (None, 14, 14,    │          0 │ block13_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2    │ (None, 14, 14,    │    752,024 │ block13_sepconv2… │
# │ (SeparableConv2D)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_bn │ (None, 14, 14,    │      4,096 │ block13_sepconv2… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 7, 7,      │    745,472 │ add_10[0][0]      │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_pool        │ (None, 7, 7,      │          0 │ block13_sepconv2… │
# │ (MaxPooling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7,      │      4,096 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 7, 7,      │          0 │ block13_pool[0][… │
# │                     │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1    │ (None, 7, 7,      │  1,582,080 │ add_11[0][0]      │
# │ (SeparableConv2D)   │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_bn │ (None, 7, 7,      │      6,144 │ block14_sepconv1… │
# │ (BatchNormalizatio… │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_a… │ (None, 7, 7,      │          0 │ block14_sepconv1… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2    │ (None, 7, 7,      │  3,159,552 │ block14_sepconv1… │
# │ (SeparableConv2D)   │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_bn │ (None, 7, 7,      │      8,192 │ block14_sepconv2… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_a… │ (None, 7, 7,      │          0 │ block14_sepconv2… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ block14_sepconv2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1024)      │  2,098,176 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1024)      │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 4)         │      4,100 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,963,756 (87.60 MB)
#  Trainable params: 2,102,276 (8.02 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

callbacks = [early_stop]

# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    # class_weight=class_weights,
    # callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.2706 - loss: 2.1236 - val_accuracy: 0.4098 - val_loss: 1.3383
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 559ms/step - accuracy: 0.3458 - loss: 1.4191 - val_accuracy: 0.4208 - val_loss: 1.2604
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 437ms/step - accuracy: 0.4575 - loss: 1.2872 - val_accuracy: 0.3497 - val_loss: 1.3012
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 564ms/step - accuracy: 0.4188 - loss: 1.3464 - val_accuracy: 0.4317 - val_loss: 1.2740
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 428ms/step - accuracy: 0.4509 - loss: 1.2219 - val_accuracy: 0.4208 - val_loss: 1.4149
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 527ms/step - accuracy: 0.4568 - loss: 1.2900 - val_accuracy: 0.4372 - val_loss: 1.3131
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 428ms/step - accuracy: 0.5069 - loss: 1.1395 - val_accuracy: 0.4590 - val_loss: 1.2383
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 544ms/step - accuracy: 0.5340 - loss: 1.0922 - val_accuracy: 0.4699 - val_loss: 1.2163
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 433ms/step - accuracy: 0.5087 - loss: 1.1103 - val_accuracy: 0.4863 - val_loss: 1.2139
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 544ms/step - accuracy: 0.5598 - loss: 1.0809 - val_accuracy: 0.4863 - val_loss: 1.1369
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 486ms/step - accuracy: 0.5489 - loss: 1.0913 - val_accuracy: 0.4754 - val_loss: 1.1531
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 501ms/step - accuracy: 0.5623 - loss: 1.0392 - val_accuracy: 0.4426 - val_loss: 1.1885
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 475ms/step - accuracy: 0.5204 - loss: 1.0819 - val_accuracy: 0.4754 - val_loss: 1.2200
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 437ms/step - accuracy: 0.6061 - loss: 0.9709 - val_accuracy: 0.4044 - val_loss: 1.2352
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 549ms/step - accuracy: 0.6189 - loss: 0.9842 - val_accuracy: 0.4863 - val_loss: 1.1391
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 432ms/step - accuracy: 0.5319 - loss: 1.0637 - val_accuracy: 0.5137 - val_loss: 1.1517
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 542ms/step - accuracy: 0.5670 - loss: 0.9551 - val_accuracy: 0.5410 - val_loss: 1.1053
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 422ms/step - accuracy: 0.6101 - loss: 0.9542 - val_accuracy: 0.5519 - val_loss: 1.0870
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 551ms/step - accuracy: 0.6458 - loss: 0.9626 - val_accuracy: 0.5628 - val_loss: 1.0605
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 459ms/step - accuracy: 0.6223 - loss: 0.9601 - val_accuracy: 0.5902 - val_loss: 1.0811
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 427ms/step - accuracy: 0.6506 - loss: 0.8690 - val_accuracy: 0.5301 - val_loss: 1.0983
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 537ms/step - accuracy: 0.6727 - loss: 0.8721 - val_accuracy: 0.4918 - val_loss: 1.1473
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 434ms/step - accuracy: 0.6254 - loss: 0.9523 - val_accuracy: 0.4699 - val_loss: 1.2581
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 525ms/step - accuracy: 0.6164 - loss: 0.9884 - val_accuracy: 0.4699 - val_loss: 1.1816
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 467ms/step - accuracy: 0.5976 - loss: 0.9996 - val_accuracy: 0.5082 - val_loss: 1.1897
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 417ms/step - accuracy: 0.6258 - loss: 0.8535 - val_accuracy: 0.4098 - val_loss: 1.2754
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 528ms/step - accuracy: 0.5666 - loss: 0.9796 - val_accuracy: 0.4317 - val_loss: 1.2045
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 419ms/step - accuracy: 0.5877 - loss: 0.9788 - val_accuracy: 0.5410 - val_loss: 1.0996
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 502ms/step - accuracy: 0.6427 - loss: 0.8667 - val_accuracy: 0.5082 - val_loss: 1.1378
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 426ms/step - accuracy: 0.6243 - loss: 0.8621 - val_accuracy: 0.5574 - val_loss: 1.0961
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 490ms/step - accuracy: 0.6225 - loss: 0.8602 - val_accuracy: 0.5301 - val_loss: 1.0926
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 431ms/step - accuracy: 0.6570 - loss: 0.8240 - val_accuracy: 0.5519 - val_loss: 1.0425
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 475ms/step - accuracy: 0.6861 - loss: 0.7677 - val_accuracy: 0.4481 - val_loss: 1.3786
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - accuracy: 0.5888 - loss: 1.0557 - val_accuracy: 0.5301 - val_loss: 1.1178
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 669ms/step - accuracy: 0.6931 - loss: 0.8020 - val_accuracy: 0.5246 - val_loss: 1.0981
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 427ms/step - accuracy: 0.6947 - loss: 0.7752 - val_accuracy: 0.5464 - val_loss: 1.1123
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 535ms/step - accuracy: 0.6820 - loss: 0.7717 - val_accuracy: 0.5464 - val_loss: 1.1116
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 423ms/step - accuracy: 0.7116 - loss: 0.7690 - val_accuracy: 0.5355 - val_loss: 1.1031
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 534ms/step - accuracy: 0.6720 - loss: 0.7742 - val_accuracy: 0.4973 - val_loss: 1.1810
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 423ms/step - accuracy: 0.6882 - loss: 0.8381 - val_accuracy: 0.5628 - val_loss: 1.1052
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 549ms/step - accuracy: 0.7280 - loss: 0.7846 - val_accuracy: 0.6011 - val_loss: 1.0902
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 418ms/step - accuracy: 0.6480 - loss: 0.7869 - val_accuracy: 0.5519 - val_loss: 1.1036
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 522ms/step - accuracy: 0.7255 - loss: 0.7513 - val_accuracy: 0.5738 - val_loss: 1.1280
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 429ms/step - accuracy: 0.7166 - loss: 0.7417 - val_accuracy: 0.5191 - val_loss: 1.1529
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 529ms/step - accuracy: 0.7349 - loss: 0.6549 - val_accuracy: 0.5301 - val_loss: 1.2009
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 423ms/step - accuracy: 0.7153 - loss: 0.7091 - val_accuracy: 0.5246 - val_loss: 1.1248
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 524ms/step - accuracy: 0.7323 - loss: 0.7112 - val_accuracy: 0.5628 - val_loss: 1.0976
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 425ms/step - accuracy: 0.7393 - loss: 0.6581 - val_accuracy: 0.5956 - val_loss: 1.0539
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 559ms/step - accuracy: 0.7676 - loss: 0.6550 - val_accuracy: 0.5738 - val_loss: 1.0868
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 420ms/step - accuracy: 0.6935 - loss: 0.7431 - val_accuracy: 0.5902 - val_loss: 1.0508
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 528ms/step - accuracy: 0.7744 - loss: 0.6088 - val_accuracy: 0.6011 - val_loss: 1.0382
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 416ms/step - accuracy: 0.7472 - loss: 0.6955 - val_accuracy: 0.5683 - val_loss: 1.0739
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 512ms/step - accuracy: 0.7620 - loss: 0.6194 - val_accuracy: 0.5683 - val_loss: 1.1213
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 426ms/step - accuracy: 0.7188 - loss: 0.7069 - val_accuracy: 0.6066 - val_loss: 1.0769
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 514ms/step - accuracy: 0.7145 - loss: 0.7409 - val_accuracy: 0.5410 - val_loss: 1.2022
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 426ms/step - accuracy: 0.7213 - loss: 0.7239 - val_accuracy: 0.6011 - val_loss: 1.1280
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 527ms/step - accuracy: 0.7183 - loss: 0.7063 - val_accuracy: 0.5956 - val_loss: 1.1136
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 424ms/step - accuracy: 0.7141 - loss: 0.7172 - val_accuracy: 0.5956 - val_loss: 1.0611
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 534ms/step - accuracy: 0.6845 - loss: 0.7343 - val_accuracy: 0.5683 - val_loss: 1.0681
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 438ms/step - accuracy: 0.7122 - loss: 0.6938 - val_accuracy: 0.5628 - val_loss: 1.0647
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 510ms/step - accuracy: 0.6507 - loss: 0.7829 - val_accuracy: 0.5847 - val_loss: 1.0615
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 431ms/step - accuracy: 0.7227 - loss: 0.6898 - val_accuracy: 0.5574 - val_loss: 1.1166
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 514ms/step - accuracy: 0.7797 - loss: 0.6065 - val_accuracy: 0.5792 - val_loss: 1.0906
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 454ms/step - accuracy: 0.7586 - loss: 0.5947 - val_accuracy: 0.5683 - val_loss: 1.0530
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 586ms/step - accuracy: 0.7579 - loss: 0.5874 - val_accuracy: 0.5683 - val_loss: 1.0113
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 426ms/step - accuracy: 0.7622 - loss: 0.6077 - val_accuracy: 0.5519 - val_loss: 1.1255
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 546ms/step - accuracy: 0.7097 - loss: 0.7265 - val_accuracy: 0.5519 - val_loss: 1.1340
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 431ms/step - accuracy: 0.7621 - loss: 0.6052 - val_accuracy: 0.5464 - val_loss: 1.1494
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 540ms/step - accuracy: 0.7501 - loss: 0.6310 - val_accuracy: 0.5683 - val_loss: 1.0540
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 428ms/step - accuracy: 0.7905 - loss: 0.5354 - val_accuracy: 0.5464 - val_loss: 1.1477
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 605ms/step - accuracy: 0.7827 - loss: 0.5645 - val_accuracy: 0.5683 - val_loss: 1.1622
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 525ms/step - accuracy: 0.7846 - loss: 0.5857 - val_accuracy: 0.5902 - val_loss: 1.0628
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 425ms/step - accuracy: 0.7800 - loss: 0.5593 - val_accuracy: 0.5628 - val_loss: 1.0686
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 577ms/step - accuracy: 0.7923 - loss: 0.5829 - val_accuracy: 0.5628 - val_loss: 1.0936
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 433ms/step - accuracy: 0.7870 - loss: 0.4823 - val_accuracy: 0.5738 - val_loss: 1.0655
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 509ms/step - accuracy: 0.7815 - loss: 0.5938 - val_accuracy: 0.5464 - val_loss: 1.1733
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 420ms/step - accuracy: 0.8150 - loss: 0.5333 - val_accuracy: 0.5519 - val_loss: 1.0671
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 494ms/step - accuracy: 0.7691 - loss: 0.5619 - val_accuracy: 0.5847 - val_loss: 1.0754
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 428ms/step - accuracy: 0.8412 - loss: 0.4949 - val_accuracy: 0.5628 - val_loss: 1.1051
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 541ms/step - accuracy: 0.7767 - loss: 0.5522 - val_accuracy: 0.6175 - val_loss: 1.0663
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 428ms/step - accuracy: 0.8041 - loss: 0.5076 - val_accuracy: 0.5792 - val_loss: 1.1149
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 528ms/step - accuracy: 0.7656 - loss: 0.6025 - val_accuracy: 0.6230 - val_loss: 1.0075
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 420ms/step - accuracy: 0.8365 - loss: 0.4635 - val_accuracy: 0.5301 - val_loss: 1.2810
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 539ms/step - accuracy: 0.7670 - loss: 0.5964 - val_accuracy: 0.5902 - val_loss: 1.1379
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 419ms/step - accuracy: 0.8117 - loss: 0.5231 - val_accuracy: 0.6011 - val_loss: 1.1314
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 534ms/step - accuracy: 0.7803 - loss: 0.5469 - val_accuracy: 0.5628 - val_loss: 1.1060
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 423ms/step - accuracy: 0.7569 - loss: 0.5631 - val_accuracy: 0.5847 - val_loss: 1.1382
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 535ms/step - accuracy: 0.7561 - loss: 0.5873 - val_accuracy: 0.5738 - val_loss: 1.1309
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 420ms/step - accuracy: 0.7706 - loss: 0.5784 - val_accuracy: 0.5847 - val_loss: 1.2377
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 533ms/step - accuracy: 0.7736 - loss: 0.6133 - val_accuracy: 0.5956 - val_loss: 1.1793
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 424ms/step - accuracy: 0.7853 - loss: 0.5389 - val_accuracy: 0.6011 - val_loss: 1.0808
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 535ms/step - accuracy: 0.7882 - loss: 0.5430 - val_accuracy: 0.5738 - val_loss: 1.1171
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 426ms/step - accuracy: 0.8206 - loss: 0.4975 - val_accuracy: 0.5847 - val_loss: 1.0681
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 531ms/step - accuracy: 0.8048 - loss: 0.5542 - val_accuracy: 0.5628 - val_loss: 1.2070
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 431ms/step - accuracy: 0.8254 - loss: 0.4949 - val_accuracy: 0.5792 - val_loss: 1.1003
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 543ms/step - accuracy: 0.8143 - loss: 0.4852 - val_accuracy: 0.5574 - val_loss: 1.1417
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 430ms/step - accuracy: 0.7848 - loss: 0.5527 - val_accuracy: 0.5956 - val_loss: 1.1378
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 536ms/step - accuracy: 0.7758 - loss: 0.5411 - val_accuracy: 0.5683 - val_loss: 1.2381
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 422ms/step - accuracy: 0.7218 - loss: 0.6327 - val_accuracy: 0.5410 - val_loss: 1.2328
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 543ms/step - accuracy: 0.8107 - loss: 0.4863 - val_accuracy: 0.5956 - val_loss: 1.1814

# %%
# Evaluate the model on the test set
train_loss, train_acc = model.evaluate(train_generator)
print(f'Train Accuracy: {train_acc:.4f}')
print(f'Train Loss: {train_loss:.4f}')

val_loss, val_acc = model.evaluate(val_generator)
print(f'Val Accuracy: {val_acc:.4f}')
print(f'Val Loss: {val_loss:.4f}')

# === EVALUASI: NILAI TERBAIK ===
best_epoch = np.argmax(history.history['val_accuracy'])
print(f"🏆 Best Epoch: {best_epoch+1}")
print(f"✅ Best Train Acc: {history.history['accuracy'][best_epoch]:.4f}")
print(f"✅ Best Val Acc: {history.history['val_accuracy'][best_epoch]:.4f}")
print(f"📉 Best Train Loss: {history.history['loss'][best_epoch]:.4f}")
print(f"📉 Best Val Loss: {history.history['val_loss'][best_epoch]:.4f}")

# Predict the test set
y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes

# Classification report
print(classification_report(y_true, y_pred_classes, target_names=['Normal', 'CIN1', 'CIN2', 'CIN3']))

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'CIN1', 'CIN2', 'CIN3'], yticklabels=['Normal', 'CIN1', 'CIN2', 'CIN3'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# ROC Curve and AUC
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure()
colors = ['blue', 'red', 'green', 'yellow']
for i, color in zip(range(4), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'ROC curve of class {i} (area = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Multi-Class')
plt.legend(loc="lower right")
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 581ms/step - accuracy: 0.8151 - loss: 0.4386
# Train Accuracy: 0.8425
# Train Loss: 0.4274
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.5960 - loss: 1.3023
# Val Accuracy: 0.5956
# Val Loss: 1.1814
# 🏆 Best Epoch: 82
# ✅ Best Train Acc: 0.7804
# ✅ Best Val Acc: 0.6230
# 📉 Best Train Loss: 0.5833
# 📉 Best Val Loss: 1.0075
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 618ms/step
#               precision    recall  f1-score   support
#
#       Normal       0.61      0.69      0.65        48
#         CIN1       0.59      0.44      0.51        45
#         CIN2       0.56      0.67      0.61        45
#         CIN3       0.63      0.58      0.60        45
#
#     accuracy                           0.60       183
#    macro avg       0.60      0.59      0.59       183
# weighted avg       0.60      0.60      0.59       183

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import recall_score, precision_score, f1_score

# Calculate sensitivity (recall), precision, and F1-score
sensitivity = recall_score(y_true, y_pred_classes, average=None)
precision = precision_score(y_true, y_pred_classes, average=None)
f1 = f1_score(y_true, y_pred_classes, average=None)

# Calculate specificity
specificity = []
for i in range(3):
    tn = np.sum((y_true != i) & (y_pred_classes != i))
    fp = np.sum((y_true != i) & (y_pred_classes == i))
    specificity.append(tn / (tn + fp))

print(f'Sensitivity: {sensitivity}')
print(f'Precision: {precision}')
print(f'F1-Score: {f1}')
print(f'Specificity: {specificity}')
# Out:
# Sensitivity: [0.6875     0.44444444 0.66666667 0.57777778]
# Precision: [0.61111111 0.58823529 0.55555556 0.63414634]
# F1-Score: [0.64705882 0.50632911 0.60606061 0.60465116]
# Specificity: [np.float64(0.8444444444444444), np.float64(0.8985507246376812), np.float64(0.8260869565217391)]

# %%
# import numpy as np
# import tensorflow as tf
# import matplotlib.pyplot as plt
# import cv2

# # Fungsi untuk membuat Grad-CAM
# def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
#     grad_model = tf.keras.models.Model(
#         [model.inputs],
#         [model.get_layer(last_conv_layer_name).output, model.output]
#     )

#     with tf.GradientTape() as tape:
#         conv_outputs, predictions = grad_model(img_array)
#         if pred_index is None:
#             pred_index = tf.argmax(predictions[0])
#         class_channel = predictions[:, pred_index]

#     grads = tape.gradient(class_channel, conv_outputs)
#     pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
#     conv_outputs = conv_outputs[0]
#     heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
#     heatmap = tf.squeeze(heatmap)
#     heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
#     return heatmap.numpy()

# # Fungsi untuk tampilkan Grad-CAM
# def show_gradcam(image_path, model, last_conv_layer_name='Conv_1'):
#     img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
#     img_array = tf.keras.preprocessing.image.img_to_array(img)
#     img_array = np.expand_dims(img_array, axis=0)
#     img_array = tf.keras.applications.mobilenet_v2.preprocess_input(img_array)

#     heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

#     img = cv2.imread(image_path)
#     img = cv2.resize(img, (224, 224))
#     heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
#     heatmap = np.uint8(255 * heatmap)
#     heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
#     superimposed_img = heatmap_color * 0.4 + img

#     plt.figure(figsize=(8, 8))
#     plt.imshow(cv2.cvtColor(superimposed_img.astype("uint8"), cv2.COLOR_BGR2RGB))
#     plt.axis('off')
#     plt.title('Grad-CAM')
#     plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import cv2
# from tensorflow.keras.preprocessing import image

# def compute_cam(model, img_path, target_size=(224, 224), class_idx=None):
#     # Ambil image dan preprocess
#     img = image.load_img(img_path, target_size=target_size)
#     img_array = image.img_to_array(img)
#     img_array = np.expand_dims(img_array, axis=0)
#     img_array = tf.keras.applications.mobilenet_v2.preprocess_input(img_array)

#     # Buat model tanpa softmax
#     cam_model = tf.keras.Model(inputs=model.input, outputs=[model.get_layer("Conv_1").output, model.output])
#     conv_outputs, predictions = cam_model.predict(img_array)

#     if class_idx is None:
#         class_idx = np.argmax(predictions[0])

#     # Ambil bobot dari FC layer terakhir
#     final_dense = model.get_layer(index=-1)  # Dense layer terakhir
#     weights = final_dense.get_weights()[0]  # shape: (num_filters, num_classes)

#     # Dot product antara feature map dan bobot class tertentu
#     cam = np.dot(conv_outputs[0], weights[:, class_idx])

#     # Normalisasi
#     cam = cv2.resize(cam, target_size)
#     cam = np.maximum(cam, 0)
#     cam = cam / cam.max()

#     # Overlay CAM
#     heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
#     img = cv2.imread(img_path)
#     img = cv2.resize(img, target_size)
#     overlay = heatmap * 0.4 + img

#     # Tampilkan
#     plt.figure(figsize=(6,6))
#     plt.imshow(cv2.cvtColor(overlay.astype("uint8"), cv2.COLOR_BGR2RGB))
#     plt.title(f'CAM untuk kelas {class_idx}')
#     plt.axis('off')
#     plt.show()

# %%
# x_batch, y_batch = next(train_generator)  # ambil batch pertama

# # Simpan 1 gambar per kelas
# class_indices = np.argmax(y_batch, axis=1)  # ubah one-hot ke label

# saved_images = {}
# for idx, label in enumerate(class_indices):
#     if label not in saved_images:
#         img = x_batch[idx]
#         img_path = f'class_{label}_sample.jpg'
#         tf.keras.preprocessing.image.save_img(img_path, img)
#         saved_images[label] = img_path

#     if len(saved_images) == 3:  # kalau sudah semua kelas ditemukan
#         break

# for label, img_path in saved_images.items():
#     print(f"\nGrad-CAM dan CAM untuk Kelas: {label}")

#     print("Grad-CAM:")
#     show_gradcam(img_path, model)

#     # print("CAM:")
#     # compute_cam(model, img_path, class_idx=label)

# %%
# x_batch, y_batch = next(val_generator)  # ambil batch pertama

# # Simpan 1 gambar per kelas
# class_indices = np.argmax(y_batch, axis=1)  # ubah one-hot ke label

# saved_images = {}
# for idx, label in enumerate(class_indices):
#     if label not in saved_images:
#         img = x_batch[idx]
#         img_path = f'class_{label}_sample.jpg'
#         tf.keras.preprocessing.image.save_img(img_path, img)
#         saved_images[label] = img_path

#     if len(saved_images) == 3:  # kalau sudah semua kelas ditemukan
#         break

# for label, img_path in saved_images.items():
#     print(f"\nGrad-CAM dan CAM untuk Kelas: {label}")

#     print("Grad-CAM:")
#     show_gradcam(img_path, model)

#     # print("CAM:")
#     # compute_cam(model, img_path, class_idx=label)
